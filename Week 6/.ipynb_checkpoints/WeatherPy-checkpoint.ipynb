# %% [markdown]
# # WeatherPy Homework Goals
# ----
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude: http://cld.wthms.co/EO3w2s/YNdUxZMrtL
# * Humidity (%) vs. Latitude: https://cld.wthms.co/bpT0ze/IyFBgMxVdD
# * Cloudiness (%) vs. Latitude: https://cld.wthms.co/JrfTdx/D6unfAUR7V
# * Wind Speed (mph) vs. Latitude: https://cld.wthms.co/4zryL2/32FTM3I5Tv
#
# Your final notebook must:
#
# * Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log (https://cld.wthms.co/F1p7lW/Z2QPWRcMLR) of each city as it's being processed with the city number and city name.
# * Save both a CSV of all data retrieved and png images for each scatter plot.

# %%
# Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import csv
import datetime
from api_keys import key
from citipy import citipy # Support docs: https://pypi.org/project/citipy/

output_data_file = "output_data/cities.csv"

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for coords in lat_lngs:
    city = citipy.nearest_city(coords[0], coords[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Convert unique list of cities to dataframe.
df = pd.DataFrame({'city_name':cities})

# Thus far, this is what we have:
df.head()
# Out:
#      city_name
# 0  pemangkat
# 1  bluff
# 2  barentsburg
# 3  najran
# 4  jamestown

# %%
# Define function to get weather for a given city.
def get_weather_for_city(row):
    url = 'https://api.openweathermap.org/data/2.5/weather?q={}&units=imperial&appid={}'.format(row['city_name'],key)
    resp = requests.get(url).json()
    if requests.get(url).status_code == 404:
        pass
    else:
        return resp

# %%
# Using function above, append weather API reponse as new column in dataframe.
pd.set_option('display.max_colwidth', -1)
df['weather_result'] = df.apply(get_weather_for_city, axis=1)

# Where there were no results in the weather API, drop the rows. Example city used for testing: "taolanaro".
df = df.dropna()

# Parse API response (weather summary) and store values in individual columns in df.
df["cloudiness"] = df['weather_result'].map(lambda x: x.get('clouds',0).get('all',0))
df["date"] = df['weather_result'].map(lambda x: x.get('dt'))
df["humidity"] = df['weather_result'].map(lambda x: x.get('main').get('humidity'))
df["lat"] = df['weather_result'].map(lambda x: x.get('coord').get('lat'))
df["long"] = df['weather_result'].map(lambda x: x.get('coord').get('lon'))
df["max_temp"] = df['weather_result'].map(lambda x: x.get('main').get('temp_max'))
df["wind_speed"] = df['weather_result'].map(lambda x: x.get('wind').get('speed'))
df["country"] = df['weather_result'].map(lambda x: x.get('sys').get('country'))

# Store results to CSV.
df.to_csv(output_data_file, sep=',', index=True, header=True)

# Show results.
df.head()
# Out:
#    city_name  \
# 1  bluff
# 3  najran
# 4  jamestown
# 5  simbahan
# 6  lingao
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         weather_result  \
# 1  {'coord': {'lon': 149.07, 'lat': -23.58}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 80.26, 'pressure': 1004.67, 'humidity': 72, 'temp_min': 80.26, 'temp_max': 80.26, 'sea_level': 1027.21, 'grnd_level': 1004.67}, 'wind': {'speed': 7.74, 'deg': 93.5019}, 'rain': {'3h': 0.725}, 'clouds': {'all': 76}, 'dt': 1547774535, 'sys': {'message': 0.0056, 'country': 'AU', 'sunrise': 1547753519, 'sunset': 1547801738}, 'id': 2175403, 'name': 'Bluff', 'cod': 200}
# 3  {'coord': {'lon': 44.22, 'lat': 17.54}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 62.6, 'pressure': 1020, 'humidity': 55, 'temp_min': 62.6, 'temp_max': 62.6}, 'visibility': 7000, 'wind': {'speed': 4.7, 'deg': 60}, 'clouds': {'all': 5}, 'dt': 1547773200, 'sys': {'type': 1, 'id': 7421, 'message': 0.0029, 'country': 'SA', 'sunrise': 1547782613, 'sunset': 1547823006}, 'id': 103630, 'name': 'Najran', 'cod': 200}
# 4  {'coord': {'lon': 138.6, 'lat': -33.21}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 91.69, 'pressure': 965.52, 'humidity': 29, 'temp_min': 91.69, 'temp_max': 91.69, 'sea_level': 1022.39, 'grnd_level': 965.52}, 'wind': {'speed': 9.57, 'deg': 160.002}, 'clouds': {'all': 76}, 'dt': 1547774543, 'sys': {'message': 0.0088, 'country': 'AU', 'sunrise': 1547754848, 'sunset': 1547805427}, 'id': 2069194, 'name': 'Jamestown', 'cod': 200}
# 5  {'coord': {'lon': 120.58, 'lat': 6.3}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.47, 'pressure': 1024.28, 'humidity': 100, 'temp_min': 81.47, 'temp_max': 81.47, 'sea_level': 1024.38, 'grnd_level': 1024.28}, 'wind': {'speed': 20.65, 'deg': 40.5019}, 'clouds': {'all': 92}, 'dt': 1547774544, 'sys': {'message': 0.0032, 'country': 'PH', 'sunrise': 1547763227, 'sunset': 1547805725}, 'id': 1695180, 'name': 'Simbahan', 'cod': 200}
# 6  {'coord': {'lon': 109.69, 'lat': 19.91}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 62.26, 'pressure': 1027.36, 'humidity': 100, 'temp_min': 62.26, 'temp_max': 62.26, 'sea_level': 1034.67, 'grnd_level': 1027.36}, 'wind': {'speed': 7.74, 'deg': 47.5019}, 'rain': {'3h': 0.17}, 'clouds': {'all': 88}, 'dt': 1547774545, 'sys': {'message': 0.0034, 'country': 'CN', 'sunrise': 1547767137, 'sunset': 1547807050}, 'id': 1803560, 'name': 'Lingao', 'cod': 200}
#
#    cloudiness        date  humidity    lat    long  max_temp  wind_speed  \
# 1  76          1547774535  72       -23.58  149.07  80.26     7.74
# 3  5           1547773200  55        17.54  44.22   62.60     4.70
# 4  76          1547774543  29       -33.21  138.60  91.69     9.57
# 5  92          1547774544  100       6.30   120.58  81.47     20.65
# 6  88          1547774545  100       19.91  109.69  62.26     7.74
#
#   country
# 1  AU
# 3  SA
# 4  AU
# 5  PH
# 6  CN

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
plt.scatter(x = df['lat'], y = df['max_temp'], s = 60, alpha=0.9 , edgecolor='black', linewidths=.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature (2019-01-17)")
plt.grid()
plt.savefig('lat_vs_temp.png')
plt.show()

# %% [markdown]
# ## Observable Trend #1
# There is a wider range of temperatures north of the equator. In other words, as you move south of the equator, temperature range less while as you move north of the equater, there is a wider range of temperatures. I suspect this is due to the tilt of the earth.

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
plt.scatter(x = df['lat'], y = df['humidity'], s = 60, alpha=0.9 , edgecolor='black', linewidths=.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2019-01-17)")
plt.grid()
plt.savefig('lat_vs_humidity.png')
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
plt.scatter(x = df['lat'], y = df['cloudiness'], s = 60, alpha=0.9 , edgecolor='black', linewidths=.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2019-01-17)")
plt.grid()
plt.savefig('lat_vs_cloudiness.png')
plt.show()

# %% [markdown]
# ## Observable Trend #2
# There is no correlation between cloudiness and location in relationship to the equator.

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
plt.scatter(x = df['lat'], y = df['wind_speed'], s = 60, alpha=0.9 , edgecolor='black', linewidths=.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed (2019-01-17)")
plt.grid()
plt.savefig('lat_vs_windspeed.png')
plt.show()

# %% [markdown]
# ## Observable Trend #3
# Wind speed doesn't vary much with regards to location in relationship to the equater and at avery latitude, the distribution of wind speed is fairly consistent. This suggests that unlike temperature, wind speed is independent of, I suspect, the tilt of the earth.
