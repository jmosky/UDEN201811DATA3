# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
from bs4 import BeautifulSoup
import requests
import pymongo
from pymongo import MongoClient
# from tqdm import tqdm

# %%
# Import NYT best sellers from 2011 to 2018.
# Source: https://data.world/typhon/new-york-times-bestsellers-from-2011-to-2018/workspace/file?filename=books_uniq_weeks.csv
nyt_bestsellers = "books_uniq_weeks.csv"
nyt_df = pd.read_csv(nyt_bestsellers)

# REMEMBER TO REMOVE THIS.
nyt_df = nyt_df.loc[(nyt_df.weeks_on_list == 5)]

# %%
# Goodreads example URL: 
#https://www.goodreads.com/search?q=1594634025

nyt_df['goodreads_url'] = 'https://www.goodreads.com/search?q=' + nyt_df['primary_isbn10']
nyt_df.head()
# Out:
#                 publisher  dagger book_review_link  \
# 129                Putnam       0              NaN
# 130             Delacorte       0              NaN
# 131  Pamela Dorman/Viking       0              NaN
# 132              Scribner       0              NaN
# 133         Little, Brown       0              NaN
#
#                                  author primary_isbn10  price primary_isbn13  \
# 129                       John Sandford     073521736X      0    9.78074E+12
# 130                      Danielle Steel     1101883960      0     9.7811E+12
# 131                          Jojo Moyes      399562478      0     9.7804E+12
# 132          Stephen King and Owen King     150116340X      0     9.7815E+12
# 133  James Patterson and Howard Roughan      316553476      0    9.78032E+12
#
#     sunday_review_link     date first_chapter_link  \
# 129                NaN   6/9/18                NaN
# 130                NaN   5/6/18                NaN
# 131                NaN  3/18/18                NaN
# 132                NaN   1/7/18                NaN
# 133                NaN  8/13/17                NaN
#
#                                contributor              title  age_group  \
# 129                       by John Sandford       TWISTED PREY        NaN
# 130                      by Danielle Steel     THE RIGHT TIME        NaN
# 131                          by Jojo Moyes           STILL ME        NaN
# 132          by Stephen King and Owen King  SLEEPING BEAUTIES        NaN
# 133  by James Patterson and Howard Roughan       MURDER GAMES        NaN
#
#      weeks_on_list                                  goodreads_url
# 129              5  https://www.goodreads.com/search?q=073521736X
# 130              5  https://www.goodreads.com/search?q=1101883960
# 131              5   https://www.goodreads.com/search?q=399562478
# 132              5  https://www.goodreads.com/search?q=150116340X
# 133              5   https://www.goodreads.com/search?q=316553476

# %%
# Get soup object.

# resp = requests.get("https://www.goodreads.com/search?q=1594634025")
# soup = BeautifulSoup(resp.content, "html.parser")
# print(soup)

def get_html(isbn):
    url = "https://www.goodreads.com/search?q={}".format(isbn)
    resp = requests.get(url)
    soup = BeautifulSoup(resp.content, "html.parser")
    return soup

nyt_df['soup_object'] = nyt_df['primary_isbn10'].map(lambda x: get_html(x))

nyt_df.head()
# Out:
#                 publisher  dagger book_review_link  \
# 129                Putnam       0              NaN
# 130             Delacorte       0              NaN
# 131  Pamela Dorman/Viking       0              NaN
# 132              Scribner       0              NaN
# 133         Little, Brown       0              NaN
#
#                                  author primary_isbn10  price primary_isbn13  \
# 129                       John Sandford     073521736X      0    9.78074E+12
# 130                      Danielle Steel     1101883960      0     9.7811E+12
# 131                          Jojo Moyes      399562478      0     9.7804E+12
# 132          Stephen King and Owen King     150116340X      0     9.7815E+12
# 133  James Patterson and Howard Roughan      316553476      0    9.78032E+12
#
#     sunday_review_link     date first_chapter_link  \
# 129                NaN   6/9/18                NaN
# 130                NaN   5/6/18                NaN
# 131                NaN  3/18/18                NaN
# 132                NaN   1/7/18                NaN
# 133                NaN  8/13/17                NaN
#
#                                contributor              title  age_group  \
# 129                       by John Sandford       TWISTED PREY        NaN
# 130                      by Danielle Steel     THE RIGHT TIME        NaN
# 131                          by Jojo Moyes           STILL ME        NaN
# 132          by Stephen King and Owen King  SLEEPING BEAUTIES        NaN
# 133  by James Patterson and Howard Roughan       MURDER GAMES        NaN
#
#      weeks_on_list                                  goodreads_url  \
# 129              5  https://www.goodreads.com/search?q=073521736X
# 130              5  https://www.goodreads.com/search?q=1101883960
# 131              5   https://www.goodreads.com/search?q=399562478
# 132              5  https://www.goodreads.com/search?q=150116340X
# 133              5   https://www.goodreads.com/search?q=316553476
#
#                                            soup_object
# 129  <!DOCTYPE html>
#
# <html class="desktop ">
# <head...
# 130  <!DOCTYPE html>
#
# <html class="desktop ">
# <head...
# 131  <!DOCTYPE html>
#
# <html class="desktop ">
# <head...
# 132  <!DOCTYPE html>
#
# <html class="desktop ">
# <head...
# 133  <!DOCTYPE html>
#
# <html class="desktop ">
# <head...

# %%
# Get rating.

def get_rating(soup_object):
    try:
        rating = soup_object.find("span", attrs={"itemprop": "ratingValue"})
        rating = rating.get_text()
        rating = rating.encode("utf-8")
        rating = rating.replace('\n', ' ')
        rating = float(rating)
        return rating
    except:
        return "not found on GoodReads"
    
nyt_df['rating'] = nyt_df['soup_object'].map(lambda x: get_rating(x))

# %%
# Get number of ratings.

def get_rating_count(soup_object):
    try:
        rating_count = soup_object.find("meta", attrs={"itemprop": "ratingCount"})
        rating_count = rating_count.get_text()
        rating_count = rating_count.replace('ratings', '').replace(',', '').strip()
        rating_count = int(rating_count)
        return rating_count
    except:
        return "not found on GoodReads"
    
nyt_df['rating_count'] = nyt_df['soup_object'].map(lambda x: get_rating_count(x))

# %%
# Get number of reviews.

def get_review_count(soup_object):
    try:
        reviews = soup_object.find("meta", attrs={"itemprop": "reviewCount"})
        reviews = reviews.get_text()
        reviews = reviews.replace('reviews', '').replace(',', '').strip()
        reviews = int(reviews)
        return reviews
    except:
        return "not found on GoodReads"
    
nyt_df['review_count'] = nyt_df['soup_object'].map(lambda x: get_review_count(x))

# %%
mongo_dict = []
for i in range(len(nyt_df)):
    temp_dict= { 
        "isbn": nyt_df.iloc[i]['primary_isbn10'],
        "publisher": nyt_df.iloc[i]['publisher'],
        "author": nyt_df.iloc[i]['author'],
        "title": nyt_df.iloc[i]['title'],
        "weeks_on_list": nyt_df.iloc[i]['weeks_on_list'],
        "goodreads_url": nyt_df.iloc[i]['goodreads_url'],
        "goodreads_html": str(nyt_df.iloc[i]['soup_object'])}
    mongo_dict.append(temp_dict)

print(type(mongo_dict))
# Out:
# <type 'list'>

# %%
client = MongoClient()
with client:
    db = client.nyt_bestsellers
    db.bestsellers.insert_many(mongo_dict)
