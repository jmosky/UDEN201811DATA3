# %%
import pandas as pd
import requests
import json
import geopy.distance

# https://developers.google.com/places/web-service/search#PlaceSearchRequests

target_coordinates = "43.6187102, -116.2146068"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": "starbucks",
    "radius": 50000,
    "key": "AIzaSyBTok6RlALK1Vm81gekooL9qxbi9zxOJSY"
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()
df = pd.DataFrame.from_records(response["results"])
df.head()
# Out:
#                                             geometry  \
# 0  {'location': {'lat': 43.60387799999999, 'lng':...
# 1  {'location': {'lat': 43.6251164, 'lng': -116.2...
# 2  {'location': {'lat': 43.6036972, 'lng': -116.2...
# 3  {'location': {'lat': 43.602111, 'lng': -116.59...
# 4  {'location': {'lat': 43.5889574, 'lng': -116.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          id       name       opening_hours  \
# 0  f29897df377a40ce4bafe7aad4999a5575fec1dd  Starbucks  {'open_now': True}
# 1  795cc2d912883132dcdabafaa48f6e0355d7b376  Starbucks  {'open_now': True}
# 2  b4effe275f1aab0c8dd9d1133450be23a8c568c9  Starbucks  {'open_now': True}
# 3  9246d3455c1d548b9d9a596e6ab0726010da84df  Starbucks  {'open_now': True}
# 4  fce8b5dc4aa672809ce1fe47b76a7aecb16db36b  Starbucks  {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 2340, 'html_attributions': ['<a hr...
# 1  [{'height': 3024, 'html_attributions': ['<a hr...
# 2  [{'height': 2448, 'html_attributions': ['<a hr...
# 3  [{'height': 664, 'html_attributions': ['<a hre...
# 4  [{'height': 2340, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJMVycwlj4rlQRyAaDM14_bkk
# 1  ChIJi1QThd74rlQRLy3zy2oDvaQ
# 2  ChIJTSJY2CdWrlQRW0qUJyTlKYA
# 3  ChIJ5dM7vJhMrlQRB1M0uuklcQ8
# 4  ChIJdYuxNXD4rlQRmrrKhITdkKk
#
#                                            plus_code  price_level  rating  \
# 0  {'compound_code': 'JQ3W+HM Boise, Idaho', 'glo...            2     3.4
# 1  {'compound_code': 'JQGR+26 Boise, Idaho', 'glo...            2     3.7
# 2  {'compound_code': 'JQ34+F3 Boise, Idaho', 'glo...            2     3.7
# 3  {'compound_code': 'JC22+RF Nampa, Idaho', 'glo...            2     4.1
# 4  {'compound_code': 'HQQM+HM Boise, Idaho', 'glo...            2     3.8
#
#                      reference   scope  \
# 0  ChIJMVycwlj4rlQRyAaDM14_bkk  GOOGLE
# 1  ChIJi1QThd74rlQRLy3zy2oDvaQ  GOOGLE
# 2  ChIJTSJY2CdWrlQRW0qUJyTlKYA  GOOGLE
# 3  ChIJ5dM7vJhMrlQRB1M0uuklcQ8  GOOGLE
# 4  ChIJdYuxNXD4rlQRmrrKhITdkKk  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [cafe, store, point_of_interest, food, establi...                  23
# 1  [cafe, store, point_of_interest, food, establi...                  23
# 2  [cafe, store, point_of_interest, food, establi...                  50
# 3  [cafe, store, point_of_interest, food, establi...                 142
# 4  [cafe, store, point_of_interest, food, establi...                  99
#
#                       vicinity
# 0  1910 W University Dr, Boise
# 1       1650 W State St, Boise
# 2    5230 W Franklin St, Boise
# 3    1451 Caldwell Blvd, Nampa
# 4      1653 S Vista Ave, Boise

# %%
# 1) how many starbucks did the API return?
df["name"].count()
# Out:
# 20

# %%
# 2) are they all starbucks, or are reg coffee shops in there?
# Yep! All SBUX.
df["name"].value_counts()
# Out:
# Starbucks    20
# Name: name, dtype: int64

# %%
# 3) what is the average distance of all the Starbucks, from the target_coordinates?

df["lat"] = df['geometry'][0]['location']['lat']
df["long"] = df['geometry'][0]['location']['lng']

#expected string: df["lat_long"] = df[['lat', 'long']].apply(lambda x: ''.join(x), axis=1)

def create_tuple(df_object):
    return (df_object.lat, df_object.long)

df['lat_long'] = df.apply(create_tuple, axis=1)
df.head()
# Out:
#                                             geometry  \
# 0  {'location': {'lat': 43.60387799999999, 'lng':...
# 1  {'location': {'lat': 43.6251164, 'lng': -116.2...
# 2  {'location': {'lat': 43.6036972, 'lng': -116.2...
# 3  {'location': {'lat': 43.602111, 'lng': -116.59...
# 4  {'location': {'lat': 43.5889574, 'lng': -116.2...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          id       name       opening_hours  \
# 0  f29897df377a40ce4bafe7aad4999a5575fec1dd  Starbucks  {'open_now': True}
# 1  795cc2d912883132dcdabafaa48f6e0355d7b376  Starbucks  {'open_now': True}
# 2  b4effe275f1aab0c8dd9d1133450be23a8c568c9  Starbucks  {'open_now': True}
# 3  9246d3455c1d548b9d9a596e6ab0726010da84df  Starbucks  {'open_now': True}
# 4  fce8b5dc4aa672809ce1fe47b76a7aecb16db36b  Starbucks  {'open_now': True}
#
#                                               photos  \
# 0  [{'height': 2340, 'html_attributions': ['<a hr...
# 1  [{'height': 3024, 'html_attributions': ['<a hr...
# 2  [{'height': 2448, 'html_attributions': ['<a hr...
# 3  [{'height': 664, 'html_attributions': ['<a hre...
# 4  [{'height': 2340, 'html_attributions': ['<a hr...
#
#                       place_id  \
# 0  ChIJMVycwlj4rlQRyAaDM14_bkk
# 1  ChIJi1QThd74rlQRLy3zy2oDvaQ
# 2  ChIJTSJY2CdWrlQRW0qUJyTlKYA
# 3  ChIJ5dM7vJhMrlQRB1M0uuklcQ8
# 4  ChIJdYuxNXD4rlQRmrrKhITdkKk
#
#                                            plus_code  price_level  rating  \
# 0  {'compound_code': 'JQ3W+HM Boise, Idaho', 'glo...            2     3.4
# 1  {'compound_code': 'JQGR+26 Boise, Idaho', 'glo...            2     3.7
# 2  {'compound_code': 'JQ34+F3 Boise, Idaho', 'glo...            2     3.7
# 3  {'compound_code': 'JC22+RF Nampa, Idaho', 'glo...            2     4.1
# 4  {'compound_code': 'HQQM+HM Boise, Idaho', 'glo...            2     3.8
#
#                      reference   scope  \
# 0  ChIJMVycwlj4rlQRyAaDM14_bkk  GOOGLE
# 1  ChIJi1QThd74rlQRLy3zy2oDvaQ  GOOGLE
# 2  ChIJTSJY2CdWrlQRW0qUJyTlKYA  GOOGLE
# 3  ChIJ5dM7vJhMrlQRB1M0uuklcQ8  GOOGLE
# 4  ChIJdYuxNXD4rlQRmrrKhITdkKk  GOOGLE
#
#                                                types  user_ratings_total  \
# 0  [cafe, store, point_of_interest, food, establi...                  23
# 1  [cafe, store, point_of_interest, food, establi...                  23
# 2  [cafe, store, point_of_interest, food, establi...                  50
# 3  [cafe, store, point_of_interest, food, establi...                 142
# 4  [cafe, store, point_of_interest, food, establi...                  99
#
#                       vicinity        lat        long  \
# 0  1910 W University Dr, Boise  43.603878 -116.203326
# 1       1650 W State St, Boise  43.603878 -116.203326
# 2    5230 W Franklin St, Boise  43.603878 -116.203326
# 3    1451 Caldwell Blvd, Nampa  43.603878 -116.203326
# 4      1653 S Vista Ave, Boise  43.603878 -116.203326
#
#                            lat_long
# 0  (43.60387799999999, -116.203326)
# 1  (43.60387799999999, -116.203326)
# 2  (43.60387799999999, -116.203326)
# 3  (43.60387799999999, -116.203326)
# 4  (43.60387799999999, -116.203326)

# %%
coords_1 = (52.2296756, 21.0122287)
coords_2 = (52.406374, 16.9251681)

print (geopy.distance.distance(coords_1, coords_2).km)
